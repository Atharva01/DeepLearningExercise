# %%
import os
import json
import numpy as np
from pathlib import Path
from glob import glob
file_path = './Labels.json'
image_path = './exercise_data'
os.chdir(os.getcwd())
file_path = Path(os.path.join(os.getcwd(),file_path)).as_posix()
image_path = Path(os.path.join(os.getcwd(),image_path))

# %%
with open(file_path) as f:
    label_dict = json.load(f)

# %%
images = list(image_path.rglob("*.npy"))

# %%
img = np.load(images[0])

# %%
images = [np.load(file) for file in list(image_path.rglob("*.npy"))]

# %%
images[0].shape
# Out:
# (32, 32, 3)

# %%
len(list(image_path.rglob("*.npy")))
# Out:
# 100

# %%
from skimage.transform import resize
from skimage import data
import matplotlib.pyplot as plt

# %%
image = data.camera()
plt.title(image.shape)
plt.imshow(image,cmap='gray')
plt.show()
image = resize(image,[50,50])
plt.title(image.shape)
plt.imshow(image,cmap='gray')
plt.show()
